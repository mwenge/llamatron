# %% [markdown]
# ##  Unpack Filth.prg

# %%
# !git clone https://github.com/larsbrinkhoff/pack-ice.git
# Out:
# Cloning into 'pack-ice'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 158 (delta 2), reused 4 (delta 2), pack-reused 152 (from 1)
# Receiving objects: 100% (158/158), 38.13 KiB | 3.81 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# !cd pack-ice && ./configure && make
# Out:
# done
# gcc -Wall -g   -c -o icecat.o icecat.c
# gcc -Wall -g   -c -o ice_info.o ice_info.c
# gcc -Wall -g   -c -o ice_crunch.o ice_crunch.c
# gcc -Wall -g   -c -o ice_decrunch.o ice_decrunch.c
# rm -f libice.a
# ar cr libice.a ice_info.o ice_crunch.o ice_decrunch.o
# ranlib libice.a
# gcc -o icecat icecat.o libice.a
# gcc -Wall -g   -c -o freeze.o freeze.c
# gcc -o freeze freeze.o libice.a
# gcc -Wall -g   -c -o melt.o melt.c
# gcc -o melt melt.o libice.a

# %%
packed_bytes = open("../orig/FILTH.PRG",'rb').read()
open(f"rude_llamatron.prg",'wb').write(packed_bytes[0x1ba:])
# Out:
# 304746

# %%
# !./pack-ice/melt rude_llamatron.prg
